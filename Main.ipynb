# %%
import tweepy
import pandas as pd
import time
import re
import numpy as np
import json

# %%
consumer_key = "9DsWGenIZLFwB86U1dQOJvbqi"
consumer_secret = "Csn5XphXA39MUWVHA9pXDhDcfpHQ1Gt24D8ppMwK0iuLwaxjbF"
access_token = "489122000-ZAe3Gb4yG9LLue0Jc7kAoFEkJO9TQsm0z9PCNGdn"
access_token_secret = "j7QqWZwgG2AczBxa9fttvKNOOxKl44u5t0gBtyxM3apGG"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
def extract_timeline_as_df(timeline_list,search_word,date_since,n_results):
    columns = set()
    allowed_types = [str, int,bool]
    tweets_data = []
    for status in tweepy.Cursor(api.search,q=search_words, lang="es", tweet_mode='extended').items(n_results):        
        try:
            status_dict = dict(vars(status))
            keys = status_dict.keys()
            single_tweet_data = {"author": status.author.screen_name,"author_id":str(status.author.id)}
            for k in keys:
                try:
                    v_type = type(status_dict[k])
                except:
                    v_type = None
                if v_type != None:
                    if v_type in allowed_types:
                        single_tweet_data[k] = status_dict[k]
                        columns.add(k)
            if 'retweeted_status' in keys:
                single_tweet_data['full_text'] = status.retweeted_status.full_text
            tweets_data.append(single_tweet_data)
        except:
            continue
    header_cols = list(columns)
    header_cols.append('author')
    header_cols.append("author_id")
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
s = ''
for g in games:
    for f in fem:
        s+=g+'+'+f+' OR '
s = s[:-4]

# %%
s
# Out:
# 'juegos+jugadoras OR juegos+mujeres OR juegos+chicas OR juegos+feminazi OR juegos+machismo OR juegos+feminismo OR videojuegos+jugadoras OR videojuegos+mujeres OR videojuegos+chicas OR videojuegos+feminazi OR videojuegos+machismo OR videojuegos+feminismo OR gaming+jugadoras OR gaming+mujeres OR gaming+chicas OR gaming+feminazi OR gaming+machismo OR gaming+feminismo OR competiciones+jugadoras OR competiciones+mujeres OR competiciones+chicas OR competiciones+feminazi OR competiciones+machismo OR competiciones+feminismo OR streaming+jugadoras OR streaming+mujeres OR streaming+chicas OR streaming+feminazi OR streaming+machismo OR streaming+feminismo'

# %%
search_words = "mujeres+videojuegos OR chicas+videojuegos OR tias+videojuegos"
date_since = "2018-11-16"

# %%
df = extract_timeline_as_df(api.home_timeline(),s,date_since,1000)

# %%
df['full_text'][100]
# Out:
# '@__iustin @EnMgtow @glz_marijose En mi caso, en el caso de los videojuegos online, las mujeres han resultado ser más tóxicas que muchos hombres...'

# %%
df = pd.read_csv('tweetsDF.csv')
df
# Out:
#      Unnamed: 0  quoted_status_id  quoted_status_id_str lang  \
# 0             0               NaN                   NaN   es
# 1             1               NaN                   NaN   es
# 2             2               NaN                   NaN   es
# 3             3               NaN                   NaN   es
# 4             4               NaN                   NaN   es
# ..          ...               ...                   ...  ...
# 273         585               NaN                   NaN   es
# 274         586               NaN                   NaN   es
# 275         587               NaN                   NaN   es
# 276         588               NaN                   NaN   es
# 277         589               NaN                   NaN   es
#
#     possibly_sensitive               id_str                   id  truncated  \
# 0                  NaN  1332662039328731138  1332662039328731138      False
# 1                  NaN  1332656127864139782  1332656127864139782      False
# 2                  NaN  1332639420701401089  1332639420701401089      False
# 3                  NaN  1332632576771633153  1332632576771633153      False
# 4                  NaN  1332626228822630403  1332626228822630403      False
# ..                 ...                  ...                  ...        ...
# 273                NaN  1329434790957883396  1329434790957883396      False
# 274                NaN  1329432613447217157  1329432613447217157      False
# 275                NaN  1329409221226606593  1329409221226606593      False
# 276              False  1329402337396482050  1329402337396482050      False
# 277                NaN  1329397541268549636  1329397541268549636      False
#
#      in_reply_to_status_id_str               source  ...  \
# 0                          NaN   Twitter for iPhone  ...
# 1                          NaN  Twitter for Android  ...
# 2                 1.332333e+18      Twitter Web App  ...
# 3                 1.332633e+18  Twitter for Android  ...
# 4                 1.332626e+18      Twitter Web App  ...
# ..                         ...                  ...  ...
# 273               1.329434e+18      Twitter Web App  ...
# 274               1.329433e+18  Twitter for Android  ...
# 275               1.329409e+18      Twitter Web App  ...
# 276               1.329400e+18      Twitter Web App  ...
# 277                        NaN            proxwitch  ...
#
#                               source_url  retweet_count  \
# 0     http://twitter.com/download/iphone              4
# 1    http://twitter.com/download/android              0
# 2             https://mobile.twitter.com              0
# 3    http://twitter.com/download/android              0
# 4             https://mobile.twitter.com              0
# ..                                   ...            ...
# 273           https://mobile.twitter.com              0
# 274  http://twitter.com/download/android              0
# 275           https://mobile.twitter.com              0
# 276           https://mobile.twitter.com              0
# 277     http://www.twitter.com/proxwitch              1
#
#     in_reply_to_user_id_str in_reply_to_user_id  is_quote_status  \
# 0                       NaN                 NaN            False
# 1                       NaN                 NaN            False
# 2              1.631909e+09        1.631909e+09            False
# 3              8.192529e+17        8.192529e+17            False
# 4              4.595703e+08        4.595703e+08            False
# ..                      ...                 ...              ...
# 273            7.018225e+07        7.018225e+07            False
# 274            3.044738e+09        3.044738e+09            False
# 275            7.536650e+17        7.536650e+17            False
# 276            3.313058e+09        3.313058e+09            False
# 277                     NaN                 NaN            False
#
#      in_reply_to_status_id  favorited  favorite_count          author  \
# 0                      NaN      False               0      carmen4366
# 1                      NaN      False               2        ansexder
# 2             1.332333e+18      False               0    Sebatian2840
# 3             1.332633e+18      False               0    Limon_Kawaii
# 4             1.332626e+18      False               0     nemuritor98
# ..                     ...        ...             ...             ...
# 273           1.329434e+18      False               1         nucaica
# 274           1.329433e+18      False               1   Pedrojose_113
# 275           1.329409e+18      False               1       JosRV2000
# 276           1.329400e+18      False               0  ObsNoctambulas
# 277                    NaN      False               0       proxWitch
#
#                author_id
# 0             2875077087
# 1    1193667502301237248
# 2             2351349126
# 3     819252867991240705
# 4              459570327
# ..                   ...
# 273            369664862
# 274           3044738452
# 275   753665009830531072
# 276           3313057823
# 277   943982708426002432
#
# [278 rows x 23 columns]

# %%
df.drop_duplicates('full_text',inplace =True)

# %%
df
# Out:
#      quoted_status_id quoted_status_id_str lang possibly_sensitive  \
# 0                 NaN                  NaN   es                NaN
# 1        1.332958e+18  1332958223330992129   es                NaN
# 2                 NaN                  NaN   es                NaN
# 4                 NaN                  NaN   es              False
# 5                 NaN                  NaN   es                NaN
# ..                ...                  ...  ...                ...
# 604      1.329722e+18  1329721722174656512   es              False
# 605               NaN                  NaN   es                NaN
# 607               NaN                  NaN   es                NaN
# 608               NaN                  NaN   es              False
# 609               NaN                  NaN   es              False
#
#                   id_str                   id  truncated  \
# 0    1333045112184709121  1333045112184709121      False
# 1    1333043749350420480  1333043749350420480      False
# 2    1333041270902710272  1333041270902710272      False
# 4    1333026095780782080  1333026095780782080      False
# 5    1333012241118081034  1333012241118081034      False
# ..                   ...                  ...        ...
# 604  1329723914436694016  1329723914436694016      False
# 605  1329720058025816065  1329720058025816065      False
# 607  1329689523006156800  1329689523006156800      False
# 608  1329686947875483651  1329686947875483651      False
# 609  1329671592146857986  1329671592146857986      False
#
#     in_reply_to_status_id_str               source in_reply_to_screen_name  \
# 0         1333043996273348609  Twitter for Android                Karrizu_
# 1                         NaN  Twitter for Android                     NaN
# 2                         NaN  Twitter for Android                     NaN
# 4                         NaN  Twitter for Android                     NaN
# 5         1333008180012572672   Twitter for iPhone            obsesiones21
# ..                        ...                  ...                     ...
# 604                       NaN   Twitter for iPhone                     NaN
# 605       1329714284218212354  Twitter for Android         TitoDeadpooloso
# 607       1329574725836812289  Twitter for Android         stivenmorales95
# 608                       NaN   Twitter for iPhone                     NaN
# 609                       NaN  Twitter for Android                     NaN
#
#      ...                           source_url retweet_count  \
# 0    ...  http://twitter.com/download/android             0
# 1    ...  http://twitter.com/download/android             4
# 2    ...  http://twitter.com/download/android             8
# 4    ...  http://twitter.com/download/android             0
# 5    ...   http://twitter.com/download/iphone             0
# ..   ...                                  ...           ...
# 604  ...   http://twitter.com/download/iphone             0
# 605  ...  http://twitter.com/download/android             0
# 607  ...  http://twitter.com/download/android             0
# 608  ...   http://twitter.com/download/iphone             0
# 609  ...  http://twitter.com/download/android             2
#
#     in_reply_to_user_id_str  in_reply_to_user_id is_quote_status  \
# 0                 587737603          587737603.0           False
# 1                       NaN                  NaN            True
# 2                       NaN                  NaN           False
# 4                       NaN                  NaN           False
# 5                  57923284           57923284.0           False
# ..                      ...                  ...             ...
# 604                     NaN                  NaN            True
# 605               107815551          107815551.0           False
# 607               177272685          177272685.0           False
# 608                     NaN                  NaN           False
# 609                     NaN                  NaN           False
#
#      in_reply_to_status_id  favorited  favorite_count          author  \
# 0             1.333044e+18      False               0        Karrizu_
# 1                      NaN      False               0     Sandychan_n
# 2                      NaN      False               0      alebarbiie
# 4                      NaN      False               0      marescrack
# 5             1.333008e+18      False               4  soris_dissastr
# ..                     ...        ...             ...             ...
# 604                    NaN      False               2      cuquiquinn
# 605           1.329714e+18      False               0        Althaell
# 607           1.329575e+18      False               2      2606Noelia
# 608                    NaN      False               0     FOlalquiaga
# 609                    NaN      False               0      lambdahugo
#
#                author_id
# 0              587737603
# 1              220345519
# 2               27141348
# 4             3204688732
# 5    1049076838042099712
# ..                   ...
# 604  1232808377417371649
# 605           2998511224
# 607  1166708502976434178
# 608  1081223882311430149
# 609             48753527
#
# [275 rows x 22 columns]

# %%
df.to_csv('tweetsDF.csv')

# %% [markdown]
# def clean_text_column(text):
#     text = text.replace('RT','')
#     text = re.sub(r"(?:\@|https?\://)\S+", "", text).strip()
#     return text

# %% [markdown]
# ## TAGS

# %%
games = ['juegos','videojuegos','gaming','competiciones','streaming']
fem = ['jugadoras','mujeres','chicas','feminazi','machismo','feminismo']
combinations = [game+','+f for game in games for f in fem]

# %%
combinations
# Out:
# ['juegos,jugadoras',
#  'juegos,mujeres',
#  'juegos,chicas',
#  'juegos,feminazi',
#  'juegos,machismo',
#  'juegos,feminismo',
#  'videojuegos,jugadoras',
#  'videojuegos,mujeres',
#  'videojuegos,chicas',
#  'videojuegos,feminazi',
#  'videojuegos,machismo',
#  'videojuegos,feminismo',
#  'gaming,jugadoras',
#  'gaming,mujeres',
#  'gaming,chicas',
#  'gaming,feminazi',
#  'gaming,machismo',
#  'gaming,feminismo',
#  'competiciones,jugadoras',
#  'competiciones,mujeres',
#  'competiciones,chicas',
#  'competiciones,feminazi',
#  'competiciones,machismo',
#  'competiciones,feminismo',
#  'streaming,jugadoras',
#  'streaming,mujeres',
#  'streaming,chicas',
#  'streaming,feminazi',
#  'streaming,machismo',
#  'streaming,feminismo']

# %% [markdown]
# ## Creating a stream listener

# %%
class MyStreamListener(tweepy.StreamListener):

    def __init__(self, api=None):
        # inherit class attributes
        super(MyStreamListener, self).__init__()
        self.num_tweets = 0
        self.file = open("tweets2.txt", "a")
        
    def on_error(self, status_code):
        if status_code == 420:
            print('420 error')
            #Ends stream in case of rate limiting
        print(status_code)
        return False 
        
    def on_status(self, status):
        tweet = status._json
        self.file.write( json.dumps(tweet) + ',\n' )
        
        self.num_tweets += 1
        if self.num_tweets < 5000:
            return True
        else:
            return False
        self.file.close()

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

# %%
myStream.filter(languages=["es"],track=games+fem, is_async=True)

# %%
st = api.get_status(390959138970140672)

# %%
st
# Out:
# Status(_api=<tweepy.api.API object at 0x000002AC5EFC64C8>, _json={'created_at': 'Thu Oct 17 21:54:57 +0000 2013', 'id': 390959138970140672, 'id_str': '390959138970140672', 'text': 'RT @RomeoRakheila on my way to vote for SRC.. call me sexist but I aint voting for no Lady..', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': 390894770417307649, 'in_reply_to_status_id_str': '390894770417307649', 'in_reply_to_user_id': 231224831, 'in_reply_to_user_id_str': '231224831', 'in_reply_to_screen_name': 'Phathutshedzo_R', 'user': {'id': 930620467, 'id_str': '930620467', 'name': "Yes You're Sexist", 'screen_name': 'YesYoureSexist', 'location': '', 'description': 'Inspired by @YesYoureRacist.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 21416, 'friends_count': 224, 'listed_count': 96, 'created_at': 'Tue Nov 06 21:56:54 +0000 2012', 'favourites_count': 1797, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 12387, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/539840373221117952/Gea8dO-o_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/539840373221117952/Gea8dO-o_normal.jpeg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2013, 10, 17, 21, 54, 57), id=390959138970140672, id_str='390959138970140672', text='RT @RomeoRakheila on my way to vote for SRC.. call me sexist but I aint voting for no Lady..', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=390894770417307649, in_reply_to_status_id_str='390894770417307649', in_reply_to_user_id=231224831, in_reply_to_user_id_str='231224831', in_reply_to_screen_name='Phathutshedzo_R', author=User(_api=<tweepy.api.API object at 0x000002AC5EFC64C8>, _json={'id': 930620467, 'id_str': '930620467', 'name': "Yes You're Sexist", 'screen_name': 'YesYoureSexist', 'location': '', 'description': 'Inspired by @YesYoureRacist.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 21416, 'friends_count': 224, 'listed_count': 96, 'created_at': 'Tue Nov 06 21:56:54 +0000 2012', 'favourites_count': 1797, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 12387, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/539840373221117952/Gea8dO-o_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/539840373221117952/Gea8dO-o_normal.jpeg', 'profile_link_color': '1DA1F2', ...

# %% [markdown]
# ## Agregate obtained values to DF

# %%
with open('improved_tweets.json') as json_file:
    data = json.load(json_file)
    columns = set()
    allowed_types = [str, int,bool]
    tweets_data = []
    for status in data:
        status = tweepy.Status().parse(None, status)
        try:
            status_dict = dict(vars(status))
            keys = status_dict.keys()
            single_tweet_data = {"author": status_dict['_json']['user']['screen_name'],"author_id":status_dict['_json']['user']['id_str']}
            for k in keys:
                try:
                    v_type = type(status_dict[k])
                except:
                    v_type = None
                if v_type != None:
                    if v_type in allowed_types:
                        single_tweet_data[k] = status_dict[k]
                        columns.add(k)
            if 'retweeted_status' in keys:
                single_tweet_data['full_text'] = status.retweeted_status.full_text
            tweets_data.append(single_tweet_data)
        except :
            continue
header_cols = list(columns)
header_cols.append('author')
header_cols.append("author_id")
df2 = pd.DataFrame(tweets_data, columns=header_cols)
df2
# Out:
#      quoted_status_id quoted_status_id_str lang possibly_sensitive  \
# 0                 NaN                  NaN   en                NaN
# 1                 NaN                  NaN   es                NaN
# 2                 NaN                  NaN  und              False
# 3                 NaN                  NaN   es                NaN
# 4                 NaN                  NaN   es                NaN
# ..                ...                  ...  ...                ...
# 437               NaN                  NaN   es              False
# 438               NaN                  NaN   en               True
# 439               NaN                  NaN   es              False
# 440               NaN                  NaN   en               True
# 441               NaN                  NaN   es              False
#
#                   id_str  reply_count                   id   timestamp_ms  \
# 0    1332749776744574976            0  1332749776744574976  1606587282726
# 1    1332749804523417600            0  1332749804523417600  1606587289349
# 2    1332749939634548743            0  1332749939634548743  1606587321562
# 3    1332750021255712769            0  1332750021255712769  1606587341022
# 4    1332750058576621568            0  1332750058576621568  1606587349920
# ..                   ...          ...                  ...            ...
# 437  1332808982264737793            0  1332808982264737793  1606601398422
# 438  1332809104201576450            0  1332809104201576450  1606601427494
# 439  1332809131397361665            0  1332809131397361665  1606601433978
# 440  1332809104201576450            0  1332809104201576450  1606601427494
# 441  1332809131397361665            0  1332809131397361665  1606601433978
#
#      truncated in_reply_to_status_id_str  ... in_reply_to_user_id  \
# 0        False                       NaN  ...                 NaN
# 1        False       1332748051786715137  ...        1.078549e+08
# 2        False                       NaN  ...                 NaN
# 3        False       1332730101709090818  ...        1.058329e+18
# 4        False       1332749140934217730  ...        1.115683e+09
# ..         ...                       ...  ...                 ...
# 437      False                       NaN  ...                 NaN
# 438      False                       NaN  ...                 NaN
# 439      False                       NaN  ...                 NaN
# 440      False                       NaN  ...                 NaN
# 441      False                       NaN  ...                 NaN
#
#     is_quote_status  in_reply_to_user_id_str filter_level  \
# 0             False                      NaN          low
# 1             False                107854938          low
# 2             False                      NaN          low
# 3             False      1058328783311249408          low
# 4             False               1115682920          low
# ..              ...                      ...          ...
# 437           False                      NaN          low
# 438           False                      NaN          low
# 439           False                      NaN          low
# 440           False                      NaN          low
# 441           False                      NaN          low
#
#      in_reply_to_status_id                                               text  \
# 0                      NaN  Black swan la pongo cuando quiero ser emo but ...
# 1             1.332748e+18  @CHERRYM0TlON lo siento 😭 a mi no me gusta, pe...
# 2                      NaN                            https://t.co/a0Kx8CPXMO
# 3             1.332730e+18  @ElEnemigo9 JAJA ANIMOO!!\nA mi al principio m...
# 4             1.332749e+18  @Miguelcraft83 @fernandorubio81 Para partirse,...
# ..                     ...                                                ...
# 437                    NaN            La buena cena 😁 https://t.co/PvCcmAyClJ
# 438                    NaN          Joinnn me live at https://t.co/vT9Xtbl3SR
# 439                    NaN  Yaaaaaa está @mbonfil_65  póngale a su canal 🥰...
# 440                    NaN          Joinnn me live at https://t.co/vT9Xtbl3SR
# 441                    NaN  Yaaaaaa está @mbonfil_65  póngale a su canal 🥰...
#
#      favorited  favorite_count           author            author_id
# 0        False               0     CHERRYM0TlON            107854938
# 1        False               0           exomcr            378282829
# 2        False               0         Tetrical            730506444
# 3        False               0       analorule9            548719958
# 4        False               0     EnApariencia   772970191139532804
# ..         ...             ...              ...                  ...
# 437      False               0      Bahamut1892           1491049057
# 438      False               0           kryznr  1323261102936018944
# 439      False               0  Astraxolotlgirl   753390369019039744
# 440      False               0           kryznr  1323261102936018944
# 441      False               0  Astraxolotlgirl   753390369019039744
#
# [442 rows x 26 columns]

# %%
df3 = pd.concat([df,df2])

# %%
df3
# Out:
#      Unnamed: 0  quoted_status_id quoted_status_id_str lang  \
# 0           0.0               NaN                  NaN   es
# 1           1.0               NaN                  NaN   es
# 2           2.0               NaN                  NaN   es
# 3           3.0               NaN                  NaN   es
# 4           4.0               NaN                  NaN   es
# ..          ...               ...                  ...  ...
# 437         NaN               NaN                  NaN   es
# 438         NaN               NaN                  NaN   en
# 439         NaN               NaN                  NaN   es
# 440         NaN               NaN                  NaN   en
# 441         NaN               NaN                  NaN   es
#
#     possibly_sensitive               id_str                   id  truncated  \
# 0                  NaN  1332662039328731138  1332662039328731138      False
# 1                  NaN  1332656127864139782  1332656127864139782      False
# 2                  NaN  1332639420701401089  1332639420701401089      False
# 3                  NaN  1332632576771633153  1332632576771633153      False
# 4                  NaN  1332626228822630403  1332626228822630403      False
# ..                 ...                  ...                  ...        ...
# 437              False  1332808982264737793  1332808982264737793      False
# 438               True  1332809104201576450  1332809104201576450      False
# 439              False  1332809131397361665  1332809131397361665      False
# 440               True  1332809104201576450  1332809104201576450      False
# 441              False  1332809131397361665  1332809131397361665      False
#
#     in_reply_to_status_id_str               source  ... in_reply_to_status_id  \
# 0                         NaN   Twitter for iPhone  ...                   NaN
# 1                         NaN  Twitter for Android  ...                   NaN
# 2                 1.33233e+18      Twitter Web App  ...          1.332333e+18
# 3                 1.33263e+18  Twitter for Android  ...          1.332633e+18
# 4                 1.33263e+18      Twitter Web App  ...          1.332626e+18
# ..                        ...                  ...  ...                   ...
# 437                       NaN  Twitter for Android  ...                   NaN
# 438                       NaN  PlayStation®Network  ...                   NaN
# 439                       NaN  Twitter for Android  ...                   NaN
# 440                       NaN  PlayStation®Network  ...                   NaN
# 441                       NaN  Twitter for Android  ...                   NaN
#
#      favorited favorite_count           author            author_id  \
# 0        False              0       carmen4366           2875077087
# 1        False              2         ansexder  1193667502301237248
# 2        False              0     Sebatian2840           2351349126
# 3        False              0     Limon_Kawaii   819252867991240705
# 4        False              0      nemuritor98            459570327
# ..         ...            ...              ...                  ...
# 437      False              0      Bahamut1892           1491049057
# 438      False              0           kryznr  1323261102936018944
# 439      False              0  Astraxolotlgirl   753390369019039744
# 440      False              0           kryznr  1323261102936018944
# 441      False              0  Astraxolotlgirl   753390369019039744
#
#     reply_count   timestamp_ms  quote_count  filter_level  \
# 0           NaN            NaN          NaN           NaN
# 1           NaN            NaN          NaN           NaN
# 2           NaN            NaN          NaN           NaN
# 3           NaN            NaN          NaN           NaN
# 4           NaN            NaN          NaN           NaN
# ..          ...            ...          ...           ...
# 437         0.0  1606601398422          0.0           low
# 438         0.0  1606601427494          0.0           low
# 439         0.0  1606601433978          0.0           low
# 440         0.0  1606601427494          0.0           low
# 441         0.0  1606601433978          0.0           low
#
#                                                   text
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 437            La buena cena 😁 https://t.co/PvCcmAyClJ
# 438          Joinnn me live at https://t.co/vT9Xtbl3SR
# 439  Yaaaaaa está @mbonfil_65  póngale a su canal 🥰...
# 440          Joinnn me live at https://t.co/vT9Xtbl3SR
# 441  Yaaaaaa está @mbonfil_65  póngale a su canal 🥰...
#
# [720 rows x 28 columns]

# %%
t = tweepy.models.Status(data[0])

# %%
stat = tweepy.Status().parse(None, data[0])

# %% [markdown]
# tweepy.Status().parse(None, data[0])

# %%
status_dict = dict(vars(stat))
keys = status_dict.keys()

# %%
for id i
