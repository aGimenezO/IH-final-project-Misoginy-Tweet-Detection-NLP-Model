# %%
! pip install spacy
! pip install pickle
# Out:
# Collecting spacy
#   Downloading spacy-2.3.4-cp37-cp37m-win_amd64.whl (9.5 MB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\alexander\anaconda3\lib\site-packages (from spacy) (4.42.1)
# Requirement already satisfied: setuptools in c:\users\alexander\anaconda3\lib\site-packages (from spacy) (45.2.0.post20200210)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp37-cp37m-win_amd64.whl (35 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp37-cp37m-win_amd64.whl (108 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\alexander\anaconda3\lib\site-packages (from spacy) (1.18.1)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp37-cp37m-win_amd64.whl (20 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp37-cp37m-win_amd64.whl (176 kB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.8.0-py3-none-any.whl (23 kB)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.4-cp37-cp37m-win_amd64.whl (887 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting blis<0.8.0,>=0.4.0; python_version >= "3.6"
#   Downloading blis-0.7.4-cp37-cp37m-win_amd64.whl (6.5 MB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\alexander\anaconda3\lib\site-packages (from spacy) (2.22.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\alexander\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.5.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\alexander\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexander\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\alexander\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\alexander\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\alexander\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (2.2.0)
# Installing collected packages: cymem, murmurhash, preshed, catalogue, srsly, wasabi, blis, plac, thinc, spacy
# Successfully installed blis-0.7.4 catalogue-1.0.0 cymem-2.0.5 murmurhash-1.0.5 plac-1.1.3 preshed-3.0.5 spacy-2.3.4 srsly-1.0.5 thinc-7.4.4 wasabi-0.8.0
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import tweepy
import pickle
import pandas as pd
import time
import re
import spacy
import numpy as np
import json
pd.set_option('display.max_colwidth', None)

# %%
nlp = spacy.load('es_core_news_sm')

# %%
machistas = pd.read_csv('misoginistic-tweets.csv')

# %%
machistas = machistas[['full_text']]

# %%
machistas['Misoginy'] = np.ones(len(machistas))

# %%
machistas = machistas.astype({'Misoginy': 'int32'})

# %%
machistas
# Out:
#                                                                                                                                                                                                                                                                                                             full_text  \
# 0                                                                                                                                                                                                                                                                                        Feminazis ni que hijueputas.
# 1                                                                                                                                                                                                                                                                        @Gonkano Locas Feminazi aborteras matabebes.
# 2                                                                                                                                                                                                                                @GermanT00752596 @TmazRsc Ahora me salieron feminazis jajaja https://t.co/gYCSQbsAhu
# 3                                                                                                                                                                                                                                   Joda aquí en Twitter si debe haber feminazi, menor tengo cuidado con lo que digo.
# 4                                                                                                                                                                                   @salartesoro No soy anti lgtb...no me molestan...ni me preocupan, son menos peligrosos que las extremistas feminazis y aborteras.
# ...                                                                                                                                                                                                                                                                                                               ...
# 2738  Lo de la sentencia de Arandina es ... desconcertante, por muchas cosas, pero Sobre todo porque les ha caído el doble de años que a los que violaron a la chica INCONSCIENTE de 14 años de Manresa.Alucino... Ya lo dije: Eso de la “inconsciencia” abrirá un nuevo camino a violadores. https://t.co/QdxjBXoMHk
# 2739                                                                                                                                                                                                                             @InesArrimadas Al final conseguirás que echemos de menos a Alberto Carlos, patética!
# 2740                        @annapratx Ay si pensamiento feminazi lésbico pero lo raro es que la lesbi en sus relaciones la mayoría usan los dedos vibradores consoladores y de más juguetes para ser penetradas entonces donde esta la lógica 🤔🤔🙄🙄 simple no les gusta los hombres pero si que las penetren jaja xds
# 2741                                                                                                                                                                                                  @roma_gallardo La secta feminazi. Si los las apoyas te respetan si los las destapas te agreden. #igualdadrealya
# 2742                                                                                                                                                                            @Manotepas @Coordinadora8m Son #Feminazis de extrema izquierda #NazionalComunista\r\n\r\nNI #PRINCIPIOSYVALORES y mucho menos cerebro
#
#       Misoginy
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2738         1
# 2739         1
# 2740         1
# 2741         1
# 2742         1
#
# [2743 rows x 2 columns]

# %%
no_machistas = pd.read_csv('non_misoginy.csv')

# %%
no_machistas['Misoginy'] = np.zeros(len(no_machistas))

# %%
no_machistas = no_machistas[['full_text','Misoginy']]

# %%
no_machistas = no_machistas.astype({'Misoginy': 'int32'})

# %%
no_machistas
# Out:
#                                                                                                                                                                                                                                                                                                                                   full_text  \
# 0                  Bravo @inMatrix5.\r\nEfectivamente, @A_LopezMaraver opinó sobre la sentencia del Arandina, sin haber tenido oportunidad de leer su contenido. \r\n\r\nDe entrada asumes la decisión de la justicia, solo dudas cuando ves contradicciones y poca base probatoria para dicha condena.\r\n\r\n#Vox https://t.co/LPQr8kxutD
# 1                                                                                                                                                                                                       @ibarweb @MAbolicion @TFeminista_ Cultura puede ser, jueces u policía lo pongo más en duda. A la sentencia de la Arandina me remito
# 2     @Persona_regular @anarob12 @Malequith Mi argumento, ESCUCHA LOS AUDIOS y ten criterio propio.\r\n\r\nCon las brujas de Salen no hubo AUDIOS y en este caso la hoguera son 38 años, algo totalmente desproporcionado cuando en España, hay condenas de 2 o 5 años en casos de muerte...\r\n\r\nSi tu argumento es insultar mal vamos 😘
# 3                                                                        La típica de: “es que yo conozco a uno del caso Arandina y sé que no haría eso” me parece tan absurdo como si la madre, el padre o algún familiar de un violador/asesino dijese que su hijo/lo q sea no sería capaz de hacer algo así. POR FAVOR, MIRAD LOS CASOS.
# 4                                                                                                                                                                                                                                  @OrbitaEduardo Y si no dice que la has violado y te manda derecho a la cárcel para los próximos 38 años.
# ...                                                                                                                                                                                                                                                                                                                                     ...
# 2644                                                                                                                                                                                                                                                                                   @jhoanaorozco01 🤣😂😂😂 viral apenas para las feminazis
# 2645                                                                                                                                                                                                                                                                                      @CashG94 JAJAJAJAJAJAJAJA me hartan las feminazis
# 2646                       @assteriaa @roxanalidia Que pena das..., es claro que tu no sabes y no está en tu ADN lo que es amor al prójimo por eso sólo sabes amenazar "si algún día te pasa algo las feminazis van a pedir justicia por ti"¿quien a pedido justicia por las Carabineras golpeadas, insultadas y quemadas por la 1ra línea?
# 2647                                                          @Juanaafanador1 Les metieron el ganzo ciego máximo con el metro, se han hecho la vista gorda sobre el tema y reniegan de machista a todo el que señale lo obvio\r\nEso, es un comportamiento feminazi\r\nA parte, ser mujer no te exenta de la critica y de los errores, niña
# 2648                                                                                                                                                                                                                                                                        Marcha feminazi, descripción gráfica!!! https://t.co/W4lyfXWZ8C
#
#       Misoginy
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2644         0
# 2645         0
# 2646         0
# 2647         0
# 2648         0
#
# [2649 rows x 2 columns]

# %%
dataset = pd.concat([machistas,no_machistas])

# %%
dataset
# Out:
#                                                                                                                                                                                                                                                                                                              full_text  \
# 0                                                                                                                                                                                                                                                                                         Feminazis ni que hijueputas.
# 1                                                                                                                                                                                                                                                                         @Gonkano Locas Feminazi aborteras matabebes.
# 2                                                                                                                                                                                                                                 @GermanT00752596 @TmazRsc Ahora me salieron feminazis jajaja https://t.co/gYCSQbsAhu
# 3                                                                                                                                                                                                                                    Joda aquí en Twitter si debe haber feminazi, menor tengo cuidado con lo que digo.
# 4                                                                                                                                                                                    @salartesoro No soy anti lgtb...no me molestan...ni me preocupan, son menos peligrosos que las extremistas feminazis y aborteras.
# ...                                                                                                                                                                                                                                                                                                                ...
# 2644                                                                                                                                                                                                                                                              @jhoanaorozco01 🤣😂😂😂 viral apenas para las feminazis
# 2645                                                                                                                                                                                                                                                                 @CashG94 JAJAJAJAJAJAJAJA me hartan las feminazis
# 2646  @assteriaa @roxanalidia Que pena das..., es claro que tu no sabes y no está en tu ADN lo que es amor al prójimo por eso sólo sabes amenazar "si algún día te pasa algo las feminazis van a pedir justicia por ti"¿quien a pedido justicia por las Carabineras golpeadas, insultadas y quemadas por la 1ra línea?
# 2647                                     @Juanaafanador1 Les metieron el ganzo ciego máximo con el metro, se han hecho la vista gorda sobre el tema y reniegan de machista a todo el que señale lo obvio\r\nEso, es un comportamiento feminazi\r\nA parte, ser mujer no te exenta de la critica y de los errores, niña
# 2648                                                                                                                                                                                                                                                   Marcha feminazi, descripción gráfica!!! https://t.co/W4lyfXWZ8C
#
#       Misoginy
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2644         0
# 2645         0
# 2646         0
# 2647         0
# 2648         0
#
# [5392 rows x 2 columns]

# %%
dataset.columns
# Out:
# Index(['full_text', 'Misoginy'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X = dataset.drop('Misoginy',axis=1)

# %%
y = dataset['Misoginy']

# %%
dataset

# %%
lista = []
for row in dataset.full_text:
    row = re.sub(r"(?:\@|https?\://)\S+", "", row)
    lista.append(row)
dataset.full_text = lista

# %%
dataset['doc'] = [nlp(text) for text in dataset.full_text]

# %%
dataset
# Out:
#                                                                                                                                                                                                                                                                                        full_text  \
# 0                                                                                                                                                                                                                                                                   Feminazis ni que hijueputas.
# 1                                                                                                                                                                                                                                                            Locas Feminazi aborteras matabebes.
# 2                                                                                                                                                                                                                                                            Ahora me salieron feminazis jajaja
# 3                                                                                                                                                                                                              Joda aquí en Twitter si debe haber feminazi, menor tengo cuidado con lo que digo.
# 4                                                                                                                                                                           No soy anti lgtb...no me molestan...ni me preocupan, son menos peligrosos que las extremistas feminazis y aborteras.
# ...                                                                                                                                                                                                                                                                                          ...
# 2644                                                                                                                                                                                                                                                        🤣😂😂😂 viral apenas para las feminazis
# 2645                                                                                                                                                                                                                                                    JAJAJAJAJAJAJAJA me hartan las feminazis
# 2646    Que pena das..., es claro que tu no sabes y no está en tu ADN lo que es amor al prójimo por eso sólo sabes amenazar "si algún día te pasa algo las feminazis van a pedir justicia por ti"¿quien a pedido justicia por las Carabineras golpeadas, insultadas y quemadas por la 1ra línea?
# 2647                               Les metieron el ganzo ciego máximo con el metro, se han hecho la vista gorda sobre el tema y reniegan de machista a todo el que señale lo obvio\r\nEso, es un comportamiento feminazi\r\nA parte, ser mujer no te exenta de la critica y de los errores, niña
# 2648                                                                                                                                                                                                                                                    Marcha feminazi, descripción gráfica!!!
#
#       Misoginy  \
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2644         0
# 2645         0
# 2646         0
# 2647         0
# 2648         0
#
#                                                                                                                                                                                                                                                                                                                                                                 doc
# 0                                                                                                                                                                                                                                                                                                                               (Feminazis, ni, que, hijueputas, .)
# 1                                                                                                                                                                                                                                                                                                                     ( , Locas, Feminazi, aborteras, matabebes, .)
# 2                                                                                                                                                                                                                                                                                                                      (  , Ahora, me, salieron, feminazis, jajaja)
# 3                                                                                                                                                                                                                                                             (Joda, aquí, en, Twitter, si, debe, haber, feminazi, ,, menor, tengo, cuidado, con, lo, que, digo, .)
# 4                                                                                                                                                                                                             ( , No, soy, anti, lgtb, ..., no, me, molestan, ..., ni, me, preocupan, ,, son, menos, peligrosos, que, las, extremistas, feminazis, y, aborteras, .)
# ...                                                                                                                                                                                                                                                                                                                                                             ...
# 2644                                                                                                                                                                                                                                                                                                           ( , 🤣, 😂, 😂, 😂, viral, apenas, para, las, feminazis)
# 2645                                                                                                                                                                                                                                                                                                              ( , JAJAJAJAJAJAJAJA, me, hartan, las, feminazis)
# 2646  (  , Que, pena, das, ..., ,, es, claro, que, tu, no, sabes, y, no, está, en, tu, ADN, lo, que, es, amor, al, prójimo, por, eso, sólo, sabes, amenazar, ", si, algún, día, te, pasa, algo, las, feminazis, van, a, pedir, justicia, por, ti"¿quien, a, pedido, justicia, por, las, Carabineras, golpeadas, ,, insultadas, y, quemadas, por, la, 1ra, línea, ?)
# 2647                               ( , Les, metieron, el, ganzo, ciego, máximo, con, el, metro, ,, se, han, hecho, la, vista, gorda, sobre, el, tema, y, reniegan, de, machista, a, todo, el, que, señale, lo, obvio, \r\n, Eso, ,, es, un, comportamiento, feminazi, \r\n, A, parte, ,, ser, mujer, no, te, exenta, de, la, critica, y, de, los, errores, ,, niña)
# 2648                                                                                                                                                                                                                                                                                                           (Marcha, feminazi, ,, descripción, gráfica, !, !, !)
#
# [5392 rows x 3 columns]

# %%
def apply_cleaning(string):
    """
    This function takes a sentence and returns a clean text
    """
    doc = nlp(clean_text(string))
    l_token = [token.text for token in doc if not token.is_punct | token.is_space | token.is_stop | 
               token.is_digit | token.like_url | token.like_num | token.like_email & token.is_oov]
    return " ".join(l_token)
tokens_to_drop=["+"]

# %%
def clean_url(str_text_raw):
    """This function eliminate a string URL in a given text"""
    str_text = re.sub("url_\S+", "", str_text_raw)
    str_text = re.sub("email_\S+", "", str_text)
    str_text = re.sub("phone_\S+", "", str_text)
    return(re.sub("http[s]?://\S+", "", str_text))
    
def clean_punctuation(str_text_raw):
    """This function replace some of the troublemaker puntuation elements in a given text"""
    return(re.sub("[$\(\)/|{|\}#~\[\]^#;:!?¿]", " ", str_text_raw))

def clean_unicode(str_text_raw):
    """This function eliminate non-unicode text"""
    str_text = re.sub("&amp;", "", str_text_raw)
    return(re.sub(r"[^\x00-\x7F]+"," ", str_text))
                      
def clean_dot_words(str_text_raw):
    """This function replace dots between words"""
    return(re.sub(r"(\w+)\.+(\w+)", r"\1 \2",str_text_raw))

def clean_text(str_text_raw):
    """This function sets the text to lowercase and applies previous cleaning functions """
    str_text = str_text_raw.lower()
    str_text = clean_dot_words(clean_punctuation(clean_unicode(clean_url(str_text))))
    return(str_text)

# %%
def string_to_token(string, str_pickle = None):
    """
    This function takes a sentence and returns the list of tokens and all their information
    * Text: The original text of the lemma.
    * Lemma: Lemma.
    * Orth: The hash value of the lemma.
    * is alpha: Does the lemma consist of alphabetic characters?
    * is digit: Does the lemma consist of digits?
    * is_title: Is the token in titlecase? 
    * is_punct: Is the token punctuation?
    * is_space: Does the token consist of whitespace characters?
    * is_stop: Is the token part of a “stop list”?
    * is_digit: Does the token consist of digits?
    * lang: Language of the token
    * tag: Fine-grained part-of-speech. The complete list is in: 
    https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html, also using: spacy.explain("RB")
    * pos: Coarse-grained part-of-speech.
    * has_vector: A boolean value indicating whether a word vector is associated with the token.
    * vector_norm: The L2 norm of the token’s vector representation.
    * is_ovv: """
    doc = nlp(string)
    l_token = [[token.text, token.lemma_, token.orth, token.is_alpha, token.is_digit, token.is_title, token.lang_, 
        token.tag_, token.pos_, token.has_vector, token.vector_norm, token.is_oov]
        for token in doc if not token.is_punct | token.is_space | token.is_stop | token.is_digit | token.like_url 
               | token.like_num | token.like_email & token.is_oov]
    pd_token = pd.DataFrame(l_token, columns=["text", "lemma", "orth", "is_alpha", "is_digit", "is_title", "language",
                                          "tag", "part_of_speech", "has_vector", "vector_norm", "is_oov"])
    #drop problematic tokens
    pd_token = pd_token[~pd_token["text"].isin(tokens_to_drop)]
    #Convert plural text to singular
    pd_token["text_to_singular"] = np.where(pd_token["tag"].isin(["NNPS", "NNS"]), pd_token["lemma"], pd_token["text"])
    if(str_pickle!=None):
        pd_token.to_pickle(f"data/output_pickles/{str_pickle}.pkl") #Modified
    del l_token
    return(pd_token)

# %% [markdown]
# # WORD2VEC

# %%
a = dataset['doc'].values[0].vector

# %%
a
# Out:
# array([ 1.1325356 ,  0.6857309 , -0.11009049,  0.12887092, -0.9907812 ,
#         0.13633749,  1.4203815 ,  0.09762733, -0.56012   , -0.45792723,
#         0.39238423, -0.35459942,  0.30529663,  1.1289042 , -0.37845427,
#         1.1168165 ,  0.1186863 ,  0.05853577,  0.14064546,  0.86107427,
#        -1.1596153 , -0.11208272,  0.13841276, -0.81370544,  0.1270121 ,
#         1.1362422 ,  1.1065067 , -0.05236978, -0.59220654,  1.3733709 ,
#         0.21921153, -0.31110722, -1.5103171 , -1.3704205 , -0.166611  ,
#        -0.5572327 ,  0.51623136,  0.90648764,  0.6529486 ,  0.60035914,
#         0.5991021 , -1.3464849 ,  0.48700142, -0.24431023, -0.230372  ,
#        -1.1831841 ,  0.50790656,  0.43082833,  0.49123973, -0.7050802 ,
#         1.3506038 ,  0.86407435, -0.06799956,  1.0751852 ,  1.0215228 ,
#         0.0904762 , -0.8767397 ,  0.59338033, -0.22909327,  0.2437381 ,
#         0.04222343, -0.6400668 , -0.66582716,  0.44789666, -0.15630849,
#        -1.0333948 ,  1.7812189 ,  1.593508  , -0.9168755 , -0.62236345,
#        -0.9527029 , -0.08334396, -0.01827812, -0.18908966, -0.65658605,
#         0.1066397 , -0.23046918,  0.04916878,  0.44249088, -1.1495693 ,
#         1.1219804 ,  0.9911683 , -0.03353543,  0.2010119 ,  1.0795263 ,
#         0.0590971 , -0.15911265, -0.36784762,  0.52641624, -2.130613  ,
#         0.0304853 ,  0.8547269 , -0.09722696, -0.5731376 , -0.58504486,
#         1.3117867 , -0.1187714 , -0.73595035, -0.437692  , -1.287317  ,
#         0.9896162 ,  0.7524978 , -1.0489413 ,  0.48259673, -0.27978998,
#         0.35334468,  0.43979368, -0.9413581 , -0.17405549, -2.1257408 ,
#        -0.06212571, -0.13615553,  0.45295483,  2.1062953 ,  1.8342907 ,
#        -0.81251204,  1.7815845 , -0.26178932, -0.24098265, -0.5836786 ,
#        -0.567441  ,  1.007053  , -1.3567921 , -1.1483061 , -1.7795929 ,
#         1.0889015 ,  0.2972203 , -1.3633422 ], dtype=float32)

# %%
dataset['doc'].values[0].vector[np.newaxis]
# Out:
# array([[ 1.1325356 ,  0.6857309 , -0.11009049,  0.12887092, -0.9907812 ,
#          0.13633749,  1.4203815 ,  0.09762733, -0.56012   , -0.45792723,
#          0.39238423, -0.35459942,  0.30529663,  1.1289042 , -0.37845427,
#          1.1168165 ,  0.1186863 ,  0.05853577,  0.14064546,  0.86107427,
#         -1.1596153 , -0.11208272,  0.13841276, -0.81370544,  0.1270121 ,
#          1.1362422 ,  1.1065067 , -0.05236978, -0.59220654,  1.3733709 ,
#          0.21921153, -0.31110722, -1.5103171 , -1.3704205 , -0.166611  ,
#         -0.5572327 ,  0.51623136,  0.90648764,  0.6529486 ,  0.60035914,
#          0.5991021 , -1.3464849 ,  0.48700142, -0.24431023, -0.230372  ,
#         -1.1831841 ,  0.50790656,  0.43082833,  0.49123973, -0.7050802 ,
#          1.3506038 ,  0.86407435, -0.06799956,  1.0751852 ,  1.0215228 ,
#          0.0904762 , -0.8767397 ,  0.59338033, -0.22909327,  0.2437381 ,
#          0.04222343, -0.6400668 , -0.66582716,  0.44789666, -0.15630849,
#         -1.0333948 ,  1.7812189 ,  1.593508  , -0.9168755 , -0.62236345,
#         -0.9527029 , -0.08334396, -0.01827812, -0.18908966, -0.65658605,
#          0.1066397 , -0.23046918,  0.04916878,  0.44249088, -1.1495693 ,
#          1.1219804 ,  0.9911683 , -0.03353543,  0.2010119 ,  1.0795263 ,
#          0.0590971 , -0.15911265, -0.36784762,  0.52641624, -2.130613  ,
#          0.0304853 ,  0.8547269 , -0.09722696, -0.5731376 , -0.58504486,
#          1.3117867 , -0.1187714 , -0.73595035, -0.437692  , -1.287317  ,
#          0.9896162 ,  0.7524978 , -1.0489413 ,  0.48259673, -0.27978998,
#          0.35334468,  0.43979368, -0.9413581 , -0.17405549, -2.1257408 ,
#         -0.06212571, -0.13615553,  0.45295483,  2.1062953 ,  1.8342907 ,
#         -0.81251204,  1.7815845 , -0.26178932, -0.24098265, -0.5836786 ,
#         -0.567441  ,  1.007053  , -1.3567921 , -1.1483061 , -1.7795929 ,
#          1.0889015 ,  0.2972203 , -1.3633422 ]], dtype=float32)

# %%
df = pd.DataFrame()
for i in range(0,len(dataset)):
    a = dataset['doc'].values[i].vector[np.newaxis]
    k = pd.DataFrame(a)
    k['Misoginy'] = dataset['Misoginy'].values[i]
    pd.concat([df,k])

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
c = dataset['doc'].apply(lambda x: x.vector)

# %%
vectorized_dataset = pd.DataFrame(np.array(c).T.tolist())

# %%
vectorized_dataset['Misoginy'] = list(dataset['Misoginy'])

# %%
vectorized_dataset
# Out:
#              0         1         2         3         4         5         6  \
# 0     1.132536  0.685731 -0.110090  0.128871 -0.990781  0.136337  1.420382
# 1    -1.647783 -0.060523  0.854485  0.690021  0.403201 -0.397088  1.129046
# 2     0.737515 -0.626051 -0.586915  0.123006 -0.618683 -0.101510  0.271749
# 3    -0.138466  0.386635  0.321079  0.022827  0.185076  0.440691  0.305798
# 4     0.060278  0.785889 -0.401769 -0.483333 -0.442749  0.776695  0.597425
# ...        ...       ...       ...       ...       ...       ...       ...
# 5387 -0.656450  0.017415 -0.453415  0.056911  0.885096 -0.533133  0.087591
# 5388  0.025264  1.124383  0.249031 -0.367912 -0.683824  0.098699  0.175067
# 5389  0.067928  0.489870 -0.606881 -0.082935 -0.144568  0.364237  0.422390
# 5390  0.545168  0.500002 -0.420173 -0.244848 -0.340510 -0.068005  0.493733
# 5391  0.094991 -1.343170  0.511207  0.990388 -0.306458 -0.164100  0.282103
#
#              7         8         9  ...       119       120       121  \
# 0     0.097627 -0.560120 -0.457927  ... -0.583679 -0.567441  1.007053
# 1     0.836532 -0.709575  0.509357  ...  0.951239  0.475902 -0.559314
# 2     0.303573  1.286289  1.068032  ... -1.170966 -0.109603  0.186818
# 3     0.308664  0.338720 -0.099503  ... -1.053116 -0.464199 -0.167372
# 4     0.360322 -0.397154  0.142115  ...  0.172713  0.057393  0.834135
# ...        ...       ...       ...  ...       ...       ...       ...
# 5387 -0.677401  0.608209 -0.578503  ...  0.307272 -0.201609 -0.447290
# 5388 -0.524326  0.765872 -0.311799  ...  1.805585 -1.128762 -0.001740
# 5389  0.115936  0.480054  0.505489  ... -0.425646 -0.367219  0.337654
# 5390  0.408057  0.543830  0.213691  ... -0.045075 -0.311035  0.296551
# 5391 -0.202682 -0.098419  1.163344  ... -0.773049  0.977984 -0.223239
#
#            122       123       124       125       126       127  Misoginy
# 0    -1.356792 -1.148306 -1.779593  1.088902  0.297220 -1.363342         1
# 1    -3.041744 -1.267721 -0.420585 -0.005690  1.042162 -0.439677         1
# 2    -0.225515  0.208246  0.523163 -0.297593 -0.096428  1.132116         1
# 3     1.067696  0.220410  0.200951  0.159785 -0.673162  0.279356         1
# 4    -0.632775 -0.605055 -0.109134  1.323226  0.360873  0.538389         1
# ...        ...       ...       ...       ...       ...       ...       ...
# 5387 -0.252449 -0.351979  0.481419 -0.288200  0.440948 -0.187569         0
# 5388 -0.979858  0.340876 -0.227362  0.479476  0.326775  0.084826         0
# 5389 -0.136044 -0.199771  0.018890  0.657563 -0.311660  0.170172         0
# 5390 -0.307329 -0.036994  0.040201  0.505194 -0.440800  0.300736         0
# 5391 -0.851580 -0.096769 -0.838937  0.199477  0.985421 -0.325636         0
#
# [5392 rows x 129 columns]

# %%
k
# Out:
#           0         1        2         3         4         5         6  \
# 0  1.132536  0.685731 -0.11009  0.128871 -0.990781  0.136337  1.420382
#
#           7        8         9  ...       119       120       121       122  \
# 0  0.097627 -0.56012 -0.457927  ... -0.583679 -0.567441  1.007053 -1.356792
#
#         123       124       125      126       127  Misoginy
# 0 -1.148306 -1.779593  1.088902  0.29722 -1.363342         1
#
# [1 rows x 129 columns]

# %% [markdown]
# # TFIDF

# %%
import string
punct = string.punctuation
punct
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from spacy.lang.es.stop_words import STOP_WORDS
stopwords = list(STOP_WORDS)

# %%
def text_data_cleaning(sentence):
    doc = nlp(sentence)
    tokens = []
    for token in doc:
        temp = token.lower_.strip()
        tokens.append(temp)
    cleaned_tokens = []
    for token in tokens:
        if token not in stopwords and token not in punct:
            cleaned_tokens.append(token)
    return cleaned_tokens

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import xgboost as xgb

# %%
tfidf = TfidfVectorizer(tokenizer = text_data_cleaning)
classifier = RandomForestClassifier()
params_random = {
    'n_estimators': [4000,6000],   
    'min_samples_split':[8,10,14],
    'min_samples_leaf' : [8,12,20],
    'n_jobs' : [None,2]
}
model_sel = RandomizedSearchCV(classifier, params_random)

# %%
X = dataset['full_text']
y = dataset['Misoginy']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42,shuffle=True)

# %%
clf = Pipeline([('tfidf', tfidf), ('clf', model_sel)])
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(tokenizer=<function text_data_cleaning at 0x000001C6A11D18B8>)),
#                 ('clf',
#                  RandomizedSearchCV(estimator=RandomForestClassifier(),
#                                     param_distributions={'min_samples_leaf': [8,
#                                                                               12,
#                                                                               20],
#                                                          'min_samples_split': [8,
#                                                                                10,
#                                                                                14],
#                                                          'n_estimators': [4000,
#                                                                           6000],
#                                                          'n_jobs': [None,
#                                                                     2]}))])

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.36      0.50       644
#            1       0.61      0.92      0.73       704
#
#     accuracy                           0.65      1348
#    macro avg       0.71      0.64      0.62      1348
# weighted avg       0.70      0.65      0.62      1348

# %%
model_sel.best_params_
# Out:
# {'n_jobs': 2,
#  'n_estimators': 4000,
#  'min_samples_split': 10,
#  'min_samples_leaf': 12}

# %%
pickle.dump(model_sel,open("random_forest_Grid_search.pkl", "wb"))
