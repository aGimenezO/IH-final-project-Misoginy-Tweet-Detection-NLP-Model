# %%
import tweepy
import pickle
import pandas as pd
import time
import re
import spacy
import numpy as np
import json
pd.set_option('display.max_colwidth', None)

# %%
nlp = spacy.load('c:/users/Alex/anaconda3/lib/site-packages/es_dep_news_trf/es_dep_news_trf-3.0.0a0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-28630bca34b2> in <module>
# ----> 1 nlp = spacy.load('c:/users/Alex/anaconda3/lib/site-packages/es_dep_news_trf/es_dep_news_trf-3.0.0a0')
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\__init__.py in load(name, disable, exclude, config)
#      45     RETURNS (Language): The loaded nlp object.
#      46     """
# ---> 47     return util.load_model(name, disable=disable, exclude=exclude, config=config)
#      48
#      49
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     273             return load_model_from_package(name, **kwargs)
#     274         if Path(name).exists():  # path to model data directory
# --> 275             return load_model_from_path(Path(name), **kwargs)
#     276     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     277         return load_model_from_path(name, **kwargs)
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\util.py in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     338     config_path = model_path / "config.cfg"
#     339     config = load_config(config_path, overrides=dict_to_dot(config))
# --> 340     nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#     341     return nlp.from_disk(model_path, exclude=exclude)
#     342
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\util.py in load_model_from_config(config, vocab, disable, exclude, auto_fill, validate)
#     381         exclude=exclude,
#     382         auto_fill=auto_fill,
# --> 383         validate=validate,
#     384     )
#     385     return nlp
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\language.py in from_config(cls, config, vocab, disable, exclude, meta, auto_fill, validate)
#    1604                         config=pipe_cfg,
#    1605                         validate=validate,
# -> 1606                         raw_config=raw_config,
#    1607                     )
#    1608                 else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     764                 config=config,
#     765                 raw_config=raw_config,
# --> 766                 validate=validate,
#     767             )
#     768         pipe_index = self._get_pipe_index(before, after, first, last)
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\language.py in create_pipe(self, factory_name, name, config, raw_config, validate)
#     632                 lang_code=self.lang,
#     633             )
# --> 634             raise ValueError(err)
#     635         pipe_meta = self.get_factory_meta(factory_name)
#     636         config = config or {}
#
# ValueError: [E002] Can't find factory for 'transformer' for language Spanish (es). This usually happens when spaCy calls `nlp.create_pipe` with custom component name that's not registered on the current language class. If you're using a custom component, make sure you've added the decorator `@Language.component` (for function components) or `@Language.factory` (for class components).
#
# Available factories: attribute_ruler, tok2vec, merge_noun_chunks, merge_entities, merge_subtokens, parser, entity_linker, ner, entity_ruler, lemmatizer, tagger, morphologizer, senter, sentencizer, textcat

# %%
machistas = pd.read_csv('misoginistic-tweets.csv')

# %%
machistas = machistas[['full_text']]

# %%
machistas['Misoginy'] = np.ones(len(machistas))

# %%
machistas = machistas.astype({'Misoginy': 'int32'})

# %%
machistas
# Out:
#                                                                                                                                                                                                                                                                                                             full_text  \
# 0                                                                                                                                                                                                                                                                                        Feminazis ni que hijueputas.
# 1                                                                                                                                                                                                                                                                        @Gonkano Locas Feminazi aborteras matabebes.
# 2                                                                                                                                                                                                                                @GermanT00752596 @TmazRsc Ahora me salieron feminazis jajaja https://t.co/gYCSQbsAhu
# 3                                                                                                                                                                                                                                   Joda aquí en Twitter si debe haber feminazi, menor tengo cuidado con lo que digo.
# 4                                                                                                                                                                                   @salartesoro No soy anti lgtb...no me molestan...ni me preocupan, son menos peligrosos que las extremistas feminazis y aborteras.
# ...                                                                                                                                                                                                                                                                                                               ...
# 2738  Lo de la sentencia de Arandina es ... desconcertante, por muchas cosas, pero Sobre todo porque les ha caído el doble de años que a los que violaron a la chica INCONSCIENTE de 14 años de Manresa.Alucino... Ya lo dije: Eso de la “inconsciencia” abrirá un nuevo camino a violadores. https://t.co/QdxjBXoMHk
# 2739                                                                                                                                                                                                                             @InesArrimadas Al final conseguirás que echemos de menos a Alberto Carlos, patética!
# 2740                        @annapratx Ay si pensamiento feminazi lésbico pero lo raro es que la lesbi en sus relaciones la mayoría usan los dedos vibradores consoladores y de más juguetes para ser penetradas entonces donde esta la lógica 🤔🤔🙄🙄 simple no les gusta los hombres pero si que las penetren jaja xds
# 2741                                                                                                                                                                                                  @roma_gallardo La secta feminazi. Si los las apoyas te respetan si los las destapas te agreden. #igualdadrealya
# 2742                                                                                                                                                                                @Manotepas @Coordinadora8m Son #Feminazis de extrema izquierda #NazionalComunista\n\nNI #PRINCIPIOSYVALORES y mucho menos cerebro
#
#       Misoginy
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2738         1
# 2739         1
# 2740         1
# 2741         1
# 2742         1
#
# [2743 rows x 2 columns]

# %%
no_machistas = pd.read_csv('non_misoginy.csv')

# %%
no_machistas['Misoginy'] = np.zeros(len(no_machistas))

# %%
no_machistas = no_machistas[['full_text','Misoginy']]

# %%
no_machistas = no_machistas.astype({'Misoginy': 'int32'})

# %%
no_machistas
# Out:
#                                                                                                                                                                                                                                                                                                                           full_text  \
# 0                    Bravo @inMatrix5.\nEfectivamente, @A_LopezMaraver opinó sobre la sentencia del Arandina, sin haber tenido oportunidad de leer su contenido. \n\nDe entrada asumes la decisión de la justicia, solo dudas cuando ves contradicciones y poca base probatoria para dicha condena.\n\n#Vox https://t.co/LPQr8kxutD
# 1                                                                                                                                                                                               @ibarweb @MAbolicion @TFeminista_ Cultura puede ser, jueces u policía lo pongo más en duda. A la sentencia de la Arandina me remito
# 2     @Persona_regular @anarob12 @Malequith Mi argumento, ESCUCHA LOS AUDIOS y ten criterio propio.\n\nCon las brujas de Salen no hubo AUDIOS y en este caso la hoguera son 38 años, algo totalmente desproporcionado cuando en España, hay condenas de 2 o 5 años en casos de muerte...\n\nSi tu argumento es insultar mal vamos 😘
# 3                                                                La típica de: “es que yo conozco a uno del caso Arandina y sé que no haría eso” me parece tan absurdo como si la madre, el padre o algún familiar de un violador/asesino dijese que su hijo/lo q sea no sería capaz de hacer algo así. POR FAVOR, MIRAD LOS CASOS.
# 4                                                                                                                                                                                                                          @OrbitaEduardo Y si no dice que la has violado y te manda derecho a la cárcel para los próximos 38 años.
# ...                                                                                                                                                                                                                                                                                                                             ...
# 2644                                                                                                                                                                                                                                                                           @jhoanaorozco01 🤣😂😂😂 viral apenas para las feminazis
# 2645                                                                                                                                                                                                                                                                              @CashG94 JAJAJAJAJAJAJAJA me hartan las feminazis
# 2646               @assteriaa @roxanalidia Que pena das..., es claro que tu no sabes y no está en tu ADN lo que es amor al prójimo por eso sólo sabes amenazar "si algún día te pasa algo las feminazis van a pedir justicia por ti"¿quien a pedido justicia por las Carabineras golpeadas, insultadas y quemadas por la 1ra línea?
# 2647                                                      @Juanaafanador1 Les metieron el ganzo ciego máximo con el metro, se han hecho la vista gorda sobre el tema y reniegan de machista a todo el que señale lo obvio\nEso, es un comportamiento feminazi\nA parte, ser mujer no te exenta de la critica y de los errores, niña
# 2648                                                                                                                                                                                                                                                                Marcha feminazi, descripción gráfica!!! https://t.co/W4lyfXWZ8C
#
#       Misoginy
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2644         0
# 2645         0
# 2646         0
# 2647         0
# 2648         0
#
# [2649 rows x 2 columns]

# %%
dataset = pd.concat([machistas,no_machistas])

# %%
dataset
# Out:
#                                                                                                                                                                                                                                                                                                              full_text  \
# 0                                                                                                                                                                                                                                                                                         Feminazis ni que hijueputas.
# 1                                                                                                                                                                                                                                                                         @Gonkano Locas Feminazi aborteras matabebes.
# 2                                                                                                                                                                                                                                 @GermanT00752596 @TmazRsc Ahora me salieron feminazis jajaja https://t.co/gYCSQbsAhu
# 3                                                                                                                                                                                                                                    Joda aquí en Twitter si debe haber feminazi, menor tengo cuidado con lo que digo.
# 4                                                                                                                                                                                    @salartesoro No soy anti lgtb...no me molestan...ni me preocupan, son menos peligrosos que las extremistas feminazis y aborteras.
# ...                                                                                                                                                                                                                                                                                                                ...
# 2644                                                                                                                                                                                                                                                              @jhoanaorozco01 🤣😂😂😂 viral apenas para las feminazis
# 2645                                                                                                                                                                                                                                                                 @CashG94 JAJAJAJAJAJAJAJA me hartan las feminazis
# 2646  @assteriaa @roxanalidia Que pena das..., es claro que tu no sabes y no está en tu ADN lo que es amor al prójimo por eso sólo sabes amenazar "si algún día te pasa algo las feminazis van a pedir justicia por ti"¿quien a pedido justicia por las Carabineras golpeadas, insultadas y quemadas por la 1ra línea?
# 2647                                         @Juanaafanador1 Les metieron el ganzo ciego máximo con el metro, se han hecho la vista gorda sobre el tema y reniegan de machista a todo el que señale lo obvio\nEso, es un comportamiento feminazi\nA parte, ser mujer no te exenta de la critica y de los errores, niña
# 2648                                                                                                                                                                                                                                                   Marcha feminazi, descripción gráfica!!! https://t.co/W4lyfXWZ8C
#
#       Misoginy
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2644         0
# 2645         0
# 2646         0
# 2647         0
# 2648         0
#
# [5392 rows x 2 columns]

# %%
dataset.columns
# Out:
# Index(['full_text', 'Misoginy'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X = dataset.drop('Misoginy',axis=1)

# %%
y = dataset['Misoginy']

# %%
dataset['doc'] = [nlp(text) for text in dataset.full_text]

# %%
dataset
# Out:
#                                                                                                                                                                                                                                                                                                              full_text  \
# 0                                                                                                                                                                                                                                                                                         Feminazis ni que hijueputas.
# 1                                                                                                                                                                                                                                                                         @Gonkano Locas Feminazi aborteras matabebes.
# 2                                                                                                                                                                                                                                 @GermanT00752596 @TmazRsc Ahora me salieron feminazis jajaja https://t.co/gYCSQbsAhu
# 3                                                                                                                                                                                                                                    Joda aquí en Twitter si debe haber feminazi, menor tengo cuidado con lo que digo.
# 4                                                                                                                                                                                    @salartesoro No soy anti lgtb...no me molestan...ni me preocupan, son menos peligrosos que las extremistas feminazis y aborteras.
# ...                                                                                                                                                                                                                                                                                                                ...
# 2644                                                                                                                                                                                                                                                              @jhoanaorozco01 🤣😂😂😂 viral apenas para las feminazis
# 2645                                                                                                                                                                                                                                                                 @CashG94 JAJAJAJAJAJAJAJA me hartan las feminazis
# 2646  @assteriaa @roxanalidia Que pena das..., es claro que tu no sabes y no está en tu ADN lo que es amor al prójimo por eso sólo sabes amenazar "si algún día te pasa algo las feminazis van a pedir justicia por ti"¿quien a pedido justicia por las Carabineras golpeadas, insultadas y quemadas por la 1ra línea?
# 2647                                         @Juanaafanador1 Les metieron el ganzo ciego máximo con el metro, se han hecho la vista gorda sobre el tema y reniegan de machista a todo el que señale lo obvio\nEso, es un comportamiento feminazi\nA parte, ser mujer no te exenta de la critica y de los errores, niña
# 2648                                                                                                                                                                                                                                                   Marcha feminazi, descripción gráfica!!! https://t.co/W4lyfXWZ8C
#
#       Misoginy  \
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2644         0
# 2645         0
# 2646         0
# 2647         0
# 2648         0
#
#                                                                                                                                                                                                                                                                                                                                                                                       doc
# 0                                                                                                                                                                                                                                                                                                                                                     (Feminazis, ni, que, hijueputas, .)
# 1                                                                                                                                                                                                                                                                                                                                    (@Gonkano, Locas, Feminazi, aborteras, matabebes, .)
# 2                                                                                                                                                                                                                                                                                           (@GermanT00752596, @TmazRsc, Ahora, me, salieron, feminazis, jajaja, https://t.co/gYCSQbsAhu)
# 3                                                                                                                                                                                                                                                                                   (Joda, aquí, en, Twitter, si, debe, haber, feminazi, ,, menor, tengo, cuidado, con, lo, que, digo, .)
# 4                                                                                                                                                                                                                        (@salartesoro, No, soy, anti, lgtb, ..., no, me, molestan, ..., ni, me, preocupan, ,, son, menos, peligrosos, que, las, extremistas, feminazis, y, aborteras, .)
# ...                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2644                                                                                                                                                                                                                                                                                                                   (@jhoanaorozco01, 🤣, 😂, 😂, 😂, viral, apenas, para, las, feminazis)
# 2645                                                                                                                                                                                                                                                                                                                             (@CashG94, JAJAJAJAJAJAJAJA, me, hartan, las, feminazis)
# 2646  (@assteriaa, @roxanalidia, Que, pena, das, ..., ,, es, claro, que, tu, no, sabes, y, no, está, en, tu, ADN, lo, que, es, amor, al, prójimo, por, eso, sólo, sabes, amenazar, ", si, algún, día, te, pasa, algo, las, feminazis, van, a, pedir, justicia, por, ti"¿quien, a, pedido, justicia, por, las, Carabineras, golpeadas, ,, insultadas, y, quemadas, por, la, 1ra, línea, ?)
# 2647                                           (@Juanaafanador1, Les, metieron, el, ganzo, ciego, máximo, con, el, metro, ,, se, han, hecho, la, vista, gorda, sobre, el, tema, y, reniegan, de, machista, a, todo, el, que, señale, lo, obvio, \n, Eso, ,, es, un, comportamiento, feminazi, \n, A, parte, ,, ser, mujer, no, te, exenta, de, la, critica, y, de, los, errores, ,, niña)
# 2648                                                                                                                                                                                                                                                                                                        (Marcha, feminazi, ,, descripción, gráfica, !, !, !, https://t.co/W4lyfXWZ8C)
#
# [5392 rows x 3 columns]

# %%
lista = []
for row in dataset.full_text:
    row = re.sub(r"(?:\@|https?\://)\S+", "", row)
    lista.append(row)
dataset.full_text = lista

# %%
dataset['doc'] = [nlp(text) for text in dataset.full_text]

# %%
dataset
# Out:
#                                                                                                                                                                                                                                                                                        full_text  \
# 0                                                                                                                                                                                                                                                                   Feminazis ni que hijueputas.
# 1                                                                                                                                                                                                                                                            Locas Feminazi aborteras matabebes.
# 2                                                                                                                                                                                                                                                            Ahora me salieron feminazis jajaja
# 3                                                                                                                                                                                                              Joda aquí en Twitter si debe haber feminazi, menor tengo cuidado con lo que digo.
# 4                                                                                                                                                                           No soy anti lgtb...no me molestan...ni me preocupan, son menos peligrosos que las extremistas feminazis y aborteras.
# ...                                                                                                                                                                                                                                                                                          ...
# 2644                                                                                                                                                                                                                                                        🤣😂😂😂 viral apenas para las feminazis
# 2645                                                                                                                                                                                                                                                    JAJAJAJAJAJAJAJA me hartan las feminazis
# 2646    Que pena das..., es claro que tu no sabes y no está en tu ADN lo que es amor al prójimo por eso sólo sabes amenazar "si algún día te pasa algo las feminazis van a pedir justicia por ti"¿quien a pedido justicia por las Carabineras golpeadas, insultadas y quemadas por la 1ra línea?
# 2647                                   Les metieron el ganzo ciego máximo con el metro, se han hecho la vista gorda sobre el tema y reniegan de machista a todo el que señale lo obvio\nEso, es un comportamiento feminazi\nA parte, ser mujer no te exenta de la critica y de los errores, niña
# 2648                                                                                                                                                                                                                                                    Marcha feminazi, descripción gráfica!!!
#
#       Misoginy  \
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2644         0
# 2645         0
# 2646         0
# 2647         0
# 2648         0
#
#                                                                                                                                                                                                                                                                                                                                                                 doc
# 0                                                                                                                                                                                                                                                                                                                               (Feminazis, ni, que, hijueputas, .)
# 1                                                                                                                                                                                                                                                                                                                     ( , Locas, Feminazi, aborteras, matabebes, .)
# 2                                                                                                                                                                                                                                                                                                                      (  , Ahora, me, salieron, feminazis, jajaja)
# 3                                                                                                                                                                                                                                                             (Joda, aquí, en, Twitter, si, debe, haber, feminazi, ,, menor, tengo, cuidado, con, lo, que, digo, .)
# 4                                                                                                                                                                                                             ( , No, soy, anti, lgtb, ..., no, me, molestan, ..., ni, me, preocupan, ,, son, menos, peligrosos, que, las, extremistas, feminazis, y, aborteras, .)
# ...                                                                                                                                                                                                                                                                                                                                                             ...
# 2644                                                                                                                                                                                                                                                                                                           ( , 🤣, 😂, 😂, 😂, viral, apenas, para, las, feminazis)
# 2645                                                                                                                                                                                                                                                                                                              ( , JAJAJAJAJAJAJAJA, me, hartan, las, feminazis)
# 2646  (  , Que, pena, das, ..., ,, es, claro, que, tu, no, sabes, y, no, está, en, tu, ADN, lo, que, es, amor, al, prójimo, por, eso, sólo, sabes, amenazar, ", si, algún, día, te, pasa, algo, las, feminazis, van, a, pedir, justicia, por, ti"¿quien, a, pedido, justicia, por, las, Carabineras, golpeadas, ,, insultadas, y, quemadas, por, la, 1ra, línea, ?)
# 2647                                   ( , Les, metieron, el, ganzo, ciego, máximo, con, el, metro, ,, se, han, hecho, la, vista, gorda, sobre, el, tema, y, reniegan, de, machista, a, todo, el, que, señale, lo, obvio, \n, Eso, ,, es, un, comportamiento, feminazi, \n, A, parte, ,, ser, mujer, no, te, exenta, de, la, critica, y, de, los, errores, ,, niña)
# 2648                                                                                                                                                                                                                                                                                                           (Marcha, feminazi, ,, descripción, gráfica, !, !, !)
#
# [5392 rows x 3 columns]

# %%
def apply_cleaning(string):
    """
    This function takes a sentence and returns a clean text
    """
    doc = nlp(clean_text(string))
    l_token = [token.text for token in doc if not token.is_punct | token.is_space | token.is_stop | 
               token.is_digit | token.like_url | token.like_num | token.like_email & token.is_oov]
    return " ".join(l_token)
tokens_to_drop=["+"]

# %%
def clean_url(str_text_raw):
    """This function eliminate a string URL in a given text"""
    str_text = re.sub("url_\S+", "", str_text_raw)
    str_text = re.sub("email_\S+", "", str_text)
    str_text = re.sub("phone_\S+", "", str_text)
    return(re.sub("http[s]?://\S+", "", str_text))
    
def clean_punctuation(str_text_raw):
    """This function replace some of the troublemaker puntuation elements in a given text"""
    return(re.sub("[$\(\)/|{|\}#~\[\]^#;:!?¿]", " ", str_text_raw))

def clean_unicode(str_text_raw):
    """This function eliminate non-unicode text"""
    str_text = re.sub("&amp;", "", str_text_raw)
    return(re.sub(r"[^\x00-\x7F]+"," ", str_text))
                      
def clean_dot_words(str_text_raw):
    """This function replace dots between words"""
    return(re.sub(r"(\w+)\.+(\w+)", r"\1 \2",str_text_raw))

def clean_text(str_text_raw):
    """This function sets the text to lowercase and applies previous cleaning functions """
    str_text = str_text_raw.lower()
    str_text = clean_dot_words(clean_punctuation(clean_unicode(clean_url(str_text))))
    return(str_text)

# %%
def string_to_token(string, str_pickle = None):
    """
    This function takes a sentence and returns the list of tokens and all their information
    * Text: The original text of the lemma.
    * Lemma: Lemma.
    * Orth: The hash value of the lemma.
    * is alpha: Does the lemma consist of alphabetic characters?
    * is digit: Does the lemma consist of digits?
    * is_title: Is the token in titlecase? 
    * is_punct: Is the token punctuation?
    * is_space: Does the token consist of whitespace characters?
    * is_stop: Is the token part of a “stop list”?
    * is_digit: Does the token consist of digits?
    * lang: Language of the token
    * tag: Fine-grained part-of-speech. The complete list is in: 
    https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html, also using: spacy.explain("RB")
    * pos: Coarse-grained part-of-speech.
    * has_vector: A boolean value indicating whether a word vector is associated with the token.
    * vector_norm: The L2 norm of the token’s vector representation.
    * is_ovv: """
    doc = nlp(string)
    l_token = [[token.text, token.lemma_, token.orth, token.is_alpha, token.is_digit, token.is_title, token.lang_, 
        token.tag_, token.pos_, token.has_vector, token.vector_norm, token.is_oov]
        for token in doc if not token.is_punct | token.is_space | token.is_stop | token.is_digit | token.like_url 
               | token.like_num | token.like_email & token.is_oov]
    pd_token = pd.DataFrame(l_token, columns=["text", "lemma", "orth", "is_alpha", "is_digit", "is_title", "language",
                                          "tag", "part_of_speech", "has_vector", "vector_norm", "is_oov"])
    #drop problematic tokens
    pd_token = pd_token[~pd_token["text"].isin(tokens_to_drop)]
    #Convert plural text to singular
    pd_token["text_to_singular"] = np.where(pd_token["tag"].isin(["NNPS", "NNS"]), pd_token["lemma"], pd_token["text"])
    if(str_pickle!=None):
        pd_token.to_pickle(f"data/output_pickles/{str_pickle}.pkl") #Modified
    del l_token
    return(pd_token)

# %%
print(dataset['full_text'].apply(string_to_token))
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 0   Feminazis   Feminazis  4457200593834285385      True     False      True
# 1  hijueputas  hijueputas   395334444491197915      True     False     False
#
#   language                           tag part_of_speech  has_vector  \
# 0       es                         PROPN          PROPN        True
# 1       es  NOUN__Gender=Fem|Number=Plur           NOUN        True
#
#    vector_norm  is_oov text_to_singular
# 0    29.524488    True        Feminazis
# 1    30.689486    True       hijueputas
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 0      Locas      Locas   478502337719621566      True     False      True
# 1   Feminazi   Feminazi  6487824887594696325      True     False      True
# 2  aborteras  aborteras  2665367861548384298      True     False     False
# 3  matabebes  matabebes  8942385862746670768      True     False     False
#
#   language                          tag part_of_speech  has_vector  \
# 0       es                        PROPN          PROPN        True
# 1       es                        PROPN          PROPN        True
# 2       es  ADJ__Gender=Fem|Number=Plur            ADJ        True
# 3       es             ADJ__Number=Plur            ADJ        True
#
#    vector_norm  is_oov text_to_singular
# 0    29.845598    True            Locas
# 1    31.433254    True         Feminazi
# 2    30.287342    True        aborteras
# 3    29.292679    True        matabebes
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 0   salieron      salir   7008791973559650513      True     False     False
# 1  feminazis  feminazis  18211357609086409305      True     False     False
# 2     jajaja     jajaja   9675053834862692579      True     False     False
#
#   language                                                          tag  \
# 0       es  VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# 1       es                                                        PROPN
# 2       es                                                        PROPN
#
#   part_of_speech  has_vector  vector_norm  is_oov text_to_singular
# 0           VERB        True    34.336926    True         salieron
# 1          PROPN        True    29.249933    True        feminazis
# 2          PROPN        True    27.464230    True           jajaja
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 0      Joda      Joda   7038228487259466156      True     False      True
# 1   Twitter   Twitter   7346769842919679806      True     False      True
# 2  feminazi  feminazi   9334981549551729027      True     False     False
# 3     menor     menor   6553149136610910805      True     False     False
# 4   cuidado    cuidar  13455135332164663916      True     False     False
# 5      digo     decir   9475697744358372104      True     False     False
#
#   language                                                          tag  \
# 0       es                                                        PROPN
# 1       es                                                        PROPN
# 2       es                                             ADJ__Number=Sing
# 3       es                                  ADJ__Degree=Cmp|Number=Sing
# 4       es                                NOUN__Gender=Masc|Number=Sing
# 5       es  VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin
#
#   part_of_speech  has_vector  vector_norm  is_oov text_to_singular
# 0          PROPN        True    28.411917    True             Joda
# 1          PROPN        True    33.692566    True          Twitter
# 2            ADJ        True    29.642752    True         feminazi
# 3            ADJ        True    32.529091    True            menor
# 4           NOUN        True    30.174828    True          cuidado
# 5           VERB        True    31.307493    True             digo
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           text       lemma                  orth  is_alpha  is_digit  \
# 0         anti        anti   2978443278556248726      True     False
# 1         lgtb        lgtb  10736262791498494143      True     False
# 2     molestan    molestar   1445933306963780144      True     False
# 3    preocupan   preocupar   3974972275536747115      True     False
# 4   peligrosos   peligroso  14813402343367461604      True     False
# 5  extremistas  extremista  18257611555415844830      True     False
# 6    feminazis   feminazis  18211357609086409305      True     False
# 7            y           y   9409450202036847209      True     False
# 8    aborteras   aborteras   2665367861548384298      True     False
#
#    is_title language  \
# 0     False       es
# 1     False       es
# 2     False       es
# 3     False       es
# 4     False       es
# 5     False       es
# 6     False       es
# 7     False       es
# 8     False       es
#
#                                                            tag part_of_speech  \
# 0                                                          ADJ            ADJ
# 1                                                         NOUN           INTJ
# 2  VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin            AUX
# 3  VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin            AUX
# 4                                 ADJ__Gender=Masc|Number=Plur            ADJ
# 5                                            NOUN__Number=Plur           NOUN
# 6                                             ADJ__Number=Plur            ADJ
# 7                                                        CCONJ          CCONJ
# 8                                  ADJ__Gender=Fem|Number=Plur            ADJ
#
#    has_vector  vector_norm  is_oov text_to_singular
# 0        True    31.299730    True             anti
# 1        True    28.384174    True             lgtb
# 2        True    32.614567    True         molestan
# 3        True    32.077980    True        preocupan
# 4        True    36.196495    True       peligrosos
# 5        True    30.334555    True      extremistas
# 6        True    29.864449    True        feminazis
# 7        True    31.889482    True                y
# 8        True    31.452188    True        aborteras
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 2644                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 0          🤣          🤣  14745778080316879639     False     False     False
# 1          😂          😂  12274633225176665583     False     False     False
# 2          😂          😂  12274633225176665583     False     False     False
# 3          😂          😂  12274633225176665583     False     False     False
# 4      viral      viral  13023327196378369442      True     False     False
# 5  feminazis  feminazis  18211357609086409305      True     False     False
#
#   language                           tag part_of_speech  has_vector  \
# 0       es             ADP__AdpType=Prep            ADP        True
# 1       es                         PROPN          PROPN        True
# 2       es                         PROPN          PROPN        True
# 3       es  NOUN__Gender=Fem|Number=Sing           NOUN        True
# 4       es              ADJ__Number=Sing            ADJ        True
# 5       es  NOUN__Gender=Fem|Number=Plur           NOUN        True
#
#    vector_norm  is_oov text_to_singular
# 0    31.646948    True                🤣
# 1    31.258986    True                😂
# 2    31.293247    True                😂
# 3    30.233095    True                😂
# 4    27.661451    True            viral
# 5    29.850351    True        feminazis
# 2645                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 0  JAJAJAJAJAJAJAJA  JAJAJAJAJAJAJAJA   7372603704064556269      True
# 1            hartan            hartar   9616956377179768831      True
# 2         feminazis         feminazis  18211357609086409305      True
#
#    is_digit  is_title language  \
# 0     False     False       es
# 1     False     False       es
# 2     False     False       es
#
#                                                            tag part_of_speech  \
# 0                              NUM__NumForm=Digit|NumType=Card            NUM
# 1  VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin            AUX
# 2                                 NOUN__Gender=Fem|Number=Plur           NOUN
#
#    has_vector  vector_norm  is_oov  text_to_singular
# 0        True    29.845486    True  JAJAJAJAJAJAJAJA
# 1        True    36.880268    True            hartan
# 2        True    30.045988    True         feminazis
# 2646                                                                                                                                                               text        lemma                  orth  is_alpha  is_digit  \
# 0          pena        penar  11220961469645672047      True     False
# 1           das          dar   2666547246678678851      True     False
# 2             y            y   9409450202036847209      True     False
# 3           ADN          ADN   7661861517356029763      True     False
# 4          amor         amor   7569031656004518897      True     False
# 5       prójimo      prójimo  18349516336178419242      True     False
# 6      amenazar     amenazar  17324626099870175369      True     False
# 7          pasa         paso  10594573967867045893      True     False
# 8     feminazis    feminazis  18211357609086409305      True     False
# 9             a            a  11901859001352538922      True     False
# 10        pedir        pedir  16885221007610086748      True     False
# 11     justicia     justicia  15913577758259993451      True     False
# 12    ti"¿quien    ti"¿quien   3692632587444090653     False     False
# 13            a            a  11901859001352538922      True     False
# 14       pedido        pedir   7769584920768238151      True     False
# 15     justicia     justicia  15913577758259993451      True     False
# 16  Carabineras  Carabineras   1326166093086215582      True     False
# 17    golpeadas      golpear   2273051769428665405      True     False
# 18   insultadas     insultar   1913013783713618365      True     False
# 19            y            y   9409450202036847209      True     False
# 20     quemadas       quemar   2249101688858493333      True     False
# 21          1ra          1ra  14925927920383680691     False     False
# 22        línea        líneo   4206860300322802285      True     False
#
#     is_title language  \
# 0      False       es
# 1      False       es
# 2      False       es
# 3      False       es
# 4      False       es
# 5      False       es
# 6      False       es
# 7      False       es
# 8      False       es
# 9      False       es
# 10     False       es
# 11     False       es
# 12     False       es
# 13     False       es
# 14     False       es
# 15     False       es
# 16      True       es
# 17     False       es
# 18     False       es
# 19     False       es
# 20     False       es
# 21     False       es
# 22     False       es
#
#                                                             tag  \
# 0   VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# 1                     ADJ__Gender=Fem|Number=Plur|VerbForm=Part
# 2                                                         CCONJ
# 3                                                         PROPN
# 4                                 NOUN__Gender=Masc|Number=Sing
# 5                                 NOUN__Gender=Masc|Number=Sing
# 6                                            VERB__VerbForm=Inf
# 7   VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# 8                                  NOUN__Gender=Fem|Number=Plur
# 9                                             ADP__AdpType=Prep
# 10                                           VERB__VerbForm=Inf
# 11                                 NOUN__Gender=Fem|Number=Sing
# 12                                                         NOUN
# 13                                            ADP__AdpType=Prep
# 14                   ADJ__Gender=Masc|Number=Sing|VerbForm=Part
# 15                                 NOUN__Gender=Fem|Number=Sing
# 16                                                        PROPN
# 17                    ADJ__Gender=Fem|Number=Plur|VerbForm=Part
# 18                    ADJ__Gender=Fem|Number=Plur|VerbForm=Part
# 19                                                        CCONJ
# 20                    ADJ__Gender=Fem|Number=Plur|VerbForm=Part
# 21                              NUM__NumForm=Digit|NumType=Card
# 22                                 NOUN__Gender=Fem|Number=Sing
#
#    part_of_speech  has_vector  vector_norm  is_oov text_to_singular
# 0            VERB        True    29.275612    True             pena
# 1             ADJ        True    30.586226    True              das
# 2           CCONJ        True    31.412058    True                y
# 3           PROPN        True    33.758297    True              ADN
# 4            NOUN        True    29.589233    True             amor
# 5            NOUN        True    28.964827    True          prójimo
# 6            VERB        True    36.717609    True         amenazar
# 7            VERB        True    37.232895    True             pasa
# 8            NOUN        True    31.799175    True        feminazis
# 9             ADP        True    33.052113    True                a
# 10           VERB        True    34.467262    True            pedir
# 11           NOUN        True    28.405329    True         justicia
# 12           INTJ        True    30.466208    True        ti"¿quien
# 13            ADP        True    30.260679    True                a
# 14            ADJ        True    31.728529    True           pedido
# 15           NOUN        True    27.603617    True         justicia
# 16          PROPN        True    32.266384    True      Carabineras
# 17            ADJ        True    31.658625    True        golpeadas
# 18            ADJ        True    34.809357    True       insultadas
# 19          CCONJ        True    33.330082    True                y
# 20            ADJ        True    31.908197    True         quemadas
# 21            NUM        True    29.545605    True              1ra
# 22           NOUN        True    27.573250    True            línea
# 2647                  text           lemma                  orth  is_alpha  is_digit  \
# 0         metieron           meter   3280708212632094004      True     False
# 1            ganzo           ganzo   2951715801464849302      True     False
# 2            ciego           cegar   3968203292345204349      True     False
# 3           máximo          máximo   3484713845986283104      True     False
# 4            metro           metro   1248323329335689060      True     False
# 5            vista          vestir  14611947950914949354      True     False
# 6            gorda           gordo  14689809675771326108      True     False
# 7             tema           temer   6682549395736523950      True     False
# 8                y               y   9409450202036847209      True     False
# 9         reniegan         renegar  18280022443793754015      True     False
# 10        machista        machista   5012286980890920769      True     False
# 11               a               a  11901859001352538922      True     False
# 12          señale         señalar   6828601260098424972      True     False
# 13           obvio          obviar  10981451468675554702      True     False
# 14  comportamiento  comportamiento  12826433030593133136      True     False
# 15        feminazi        feminazi   9334981549551729027      True     False
# 16               A               A  14862748245026736845      True     False
# 17           mujer           mujer   2865383744470792204      True     False
# 18          exenta          exento  12455112512448348986      True     False
# 19         critica        criticar    948483262838089060      True     False
# 20               y               y   9409450202036847209      True     False
# 21         errores           error  10280645574905748384      True     False
# 22            niña            niño  14296515436416493542      True     False
#
#     is_title language  \
# 0      False       es
# 1      False       es
# 2      False       es
# 3      False       es
# 4      False       es
# 5      False       es
# 6      False       es
# 7      False       es
# 8      False       es
# 9      False       es
# 10     False       es
# 11     False       es
# 12     False       es
# 13     False       es
# 14     False       es
# 15     False       es
# 16      True       es
# 17     False       es
# 18     False       es
# 19     False       es
# 20     False       es
# 21     False       es
# 22     False       es
#
#                                                             tag  \
# 0   VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# 1                                 NOUN__Gender=Masc|Number=Sing
# 2                                  ADJ__Gender=Masc|Number=Sing
# 3                       ADJ__Degree=Sup|Gender=Masc|Number=Sing
# 4                                 NOUN__Gender=Masc|Number=Sing
# 5                                  NOUN__Gender=Fem|Number=Sing
# 6                                   ADJ__Gender=Fem|Number=Sing
# 7                                 NOUN__Gender=Masc|Number=Sing
# 8                                                         CCONJ
# 9              VERB__Mood=Imp|Number=Plur|Person=3|VerbForm=Fin
# 10                                                         NOUN
# 11                                            ADP__AdpType=Prep
# 12  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# 13                                 ADJ__Gender=Masc|Number=Sing
# 14                                NOUN__Gender=Masc|Number=Sing
# 15                                             ADJ__Number=Sing
# 16                                            ADP__AdpType=Prep
# 17                                 NOUN__Gender=Fem|Number=Sing
# 18  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# 19                                 NOUN__Gender=Fem|Number=Sing
# 20                                                        CCONJ
# 21                                NOUN__Gender=Masc|Number=Plur
# 22                                 NOUN__Gender=Fem|Number=Sing
#
#    part_of_speech  has_vector  vector_norm  is_oov text_to_singular
# 0            VERB        True    35.993622    True         metieron
# 1            NOUN        True    28.523689    True            ganzo
# 2             ADJ        True    28.517815    True            ciego
# 3             ADJ        True    28.221554    True           máximo
# 4            NOUN        True    27.575304    True            metro
# 5            NOUN        True    27.365078    True            vista
# 6             ADJ        True    28.434334    True            gorda
# 7            NOUN        True    25.654751    True             tema
# 8           CCONJ        True    30.665953    True                y
# 9            VERB        True    31.464699    True         reniegan
# 10           INTJ        True    26.095364    True         machista
# 11            ADP        True    31.034325    True                a
# 12           VERB        True    31.818575    True           señale
# 13            ADJ        True    28.200552    True            obvio
# 14           NOUN        True    31.898346    True   comportamiento
# 15            ADJ        True    30.109232    True         feminazi
# 16            ADP        True    30.347429    True                A
# 17           NOUN        True    29.675396    True            mujer
# 18           VERB        True    28.946606    True           exenta
# 19           NOUN        True    28.101385    True          critica
# 20          CCONJ        True    30.375090    True                y
# 21           NOUN        True    30.559658    True          errores
# 22           NOUN        True    25.325792    True             niña
# 2648                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 0       Marcha       Marcha  15665671688306915209      True     False
# 1     feminazi     feminazi   9334981549551729027      True     False
# 2  descripción  descripción  11643248821392920902      True     False
# 3      gráfica      gráfico  15326023002248863895      True     False
#
#    is_title language                           tag part_of_speech  has_vector  \
# 0      True       es                         PROPN          PROPN        True
# 1     False       es              ADJ__Number=Sing            ADJ        True
# 2     False       es  NOUN__Gender=Fem|Number=Sing           NOUN        True
# 3     False       es   ADJ__Gender=Fem|Number=Sing            ADJ        True
#
#    vector_norm  is_oov text_to_singular
# 0    30.674051    True           Marcha
# 1    27.694336    True         feminazi
# 2    27.446413    True      descripción
# 3    30.232874    True          gráfica
# Name: full_text, Length: 5392, dtype: object

# %%
df = pd.DataFrame()
for i in range(len(dataset)):
    a = dataset['doc'].values[i].vector[np.newaxis].T   
    np.append(a,dataset['Misoginy'].values[i])
    pd.concat([df,pd.DataFrame(a)])

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
s = dataset['doc'].values[0].vector[np.newaxis].T

# %% [markdown]
# # STRAT B

# %%
import string
punct = string.punctuation
punct
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from spacy.lang.es.stop_words import STOP_WORDS
stopwords = list(STOP_WORDS)

# %%
def text_data_cleaning(sentence):
    doc = nlp(sentence)
    tokens = []
    for token in doc:
        temp = token.lower_.strip()
        tokens.append(temp)
    cleaned_tokens = []
    for token in tokens:
        if token not in stopwords and token not in punct:
            cleaned_tokens.append(token)
    return cleaned_tokens

# %%
text_data_cleaning(dataset['full_text'].values[1])
# Out:
# ['locas', 'feminazi', 'aborteras', 'matabebes']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
tfidf = TfidfVectorizer(tokenizer = text_data_cleaning)
classifier = RandomForestClassifier()
params_random = {
    'n_estimators': [4000,6000],   
    'min_samples_split':[8,10,14],
    'min_samples_leaf' : [8,12,20],
    'n_jobs' : [None,2]
}
model_sel = RandomizedSearchCV(classifier, params_random)

# %%
X = dataset['full_text']
y = dataset['Misoginy']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42,shuffle=True)

# %%
clf = Pipeline([('tfidf', tfidf), ('clf', model_sel)])
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(tokenizer=<function text_data_cleaning at 0x000001C6A11D18B8>)),
#                 ('clf',
#                  RandomizedSearchCV(estimator=RandomForestClassifier(),
#                                     param_distributions={'min_samples_leaf': [8,
#                                                                               12,
#                                                                               20],
#                                                          'min_samples_split': [8,
#                                                                                10,
#                                                                                14],
#                                                          'n_estimators': [4000,
#                                                                           6000],
#                                                          'n_jobs': [None,
#                                                                     2]}))])

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.36      0.50       644
#            1       0.61      0.92      0.73       704
#
#     accuracy                           0.65      1348
#    macro avg       0.71      0.64      0.62      1348
# weighted avg       0.70      0.65      0.62      1348

# %%
model_sel.best_params_
# Out:
# {'n_jobs': 2,
#  'n_estimators': 4000,
#  'min_samples_split': 10,
#  'min_samples_leaf': 12}

# %%
pickle.dump(model_sel,open("random_forest_Grid_search.pkl", "wb"))
